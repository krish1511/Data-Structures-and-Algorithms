# %% [markdown]
# # Circular Queue

# %%
class CircularQueue(): 
    
    # constructor 
    def __init__(self, size): # initializing the class 
        self.size = size 
          
        # initializing queue with none 
        self.queue = [None for i in range(size)]  
        self.front = self.rear = -1
  
    def enqueue(self, data): 
          
        # condition if queue is full 
        if ((self.rear + 1) % self.size == self.front):  
            print(" Queue is Full\n") 
            return
        # condition for empty queue 
        elif (self.rear == -1):  
            self.front = 0
            self.rear = 0
            self.queue[self.rear] = data 
        else: 
              
            # next position of rear 
            self.rear = (self.rear + 1) % self.size  
            self.queue[self.rear] = data 
              
    def dequeue(self): 
        if (self.rear == -1): # codition for empty queue 
            print ("Queue is Empty\n") 
              
        # condition for only one element 
        elif (self.front == self.rear):  
            temp=self.queue[self.front] 
            self.front = -1
            self.rear = -1
            return temp 
        else: 
            temp = self.queue[self.front] 
            self.front = (self.front + 1) % self.size 
            return temp 
  
    def display(self): 
      
        # condition for empty queue 
        if(self.front == -1):  
            print ("Queue is Empty") 
  
        elif (self.rear >= self.front): 
            print("Elements in the circular queue are:",  
                                              end = " ") 
            for i in range(self.front, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print () 
  
        else: 
            print ("Elements in Circular Queue are:",  
                                           end = " ") 
            for i in range(self.front, self.size): 
                print(self.queue[i], end = " ") 
            for i in range(0, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print () 
  
        if ((self.rear + 1) % self.size == self.front): 
            print("Queue is Full") 
  
# Driver Code 
ob = CircularQueue(5) 
ob.enqueue(14) 
ob.enqueue(22) 
ob.enqueue(13) 
ob.enqueue(-6) 
ob.display() 
print ("Deleted value = ", ob.dequeue()) 
print ("Deleted value = ", ob.dequeue()) 
ob.display() 
ob.enqueue(9) 
ob.enqueue(20) 
ob.enqueue(5) 
ob.display() 
  
# This code is contributed by AshwinGoel
# Out:
# Elements in the circular queue are: 14 22 13 -6
# Deleted value =  14
# Deleted value =  22
# Elements in the circular queue are: 13 -6
# Elements in Circular Queue are: 13 -6 9 20 5
# Queue is Full

# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.queue = [None for i in range(size)]
        self.rear = -1
        self.front = -1
        
    def enqueue(self, data):
        if (self.rear + 1) % self.size == self.front :
            print('queue is Full')
            return
        elif self.rear == -1 and self.front == -1:
            self.rear = 0
            self.front = 0
            self.queue[self.rear] = data
        else:
            self.rear = (self.rear + 1) % self.size
            self.queue[self.rear] = data
            
    def dequeue(self):
        if self.rear == -1 and self.front == -1:
            print('queue is already empty')
            return
        elif self.rear == self.front:
            popVal = self.queue[self.front]
            self.rear = -1
            self.front = -1
            return popVal
        else:
            popVal = self.queue[self.front]
            self.front = (self.front + 1) % self.size
            return popVal
            
    def display(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        
        elif self.rear >= self.front :
            print('elements in the circuar queue are', end = ' ')
            for i in range(self.front , self.rear+1):
                print(self.queue[i] ,end= '@ ')
            print()
        else:
            print('elements in circular queue are', end = ' ')
            for i in range(self.front,  self.size):
                print(self.queue[i], end='. ')
            print()
            for i in range(0, self.rear + 1):
                print(self.queue[i], end='# ')
            print()
            
        if (self.rear + 1) % self.size  == self.front:
            print('queue is full')
            return
        
cq = CircularQueue(5)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(40)
cq.display()
print('Deleted Value = ',cq.dequeue())
print('Deleted Value = ',cq.dequeue())
cq.display()
cq.enqueue(5)
cq.enqueue(6)
cq.enqueue(7)
cq.display()
# Out:
# elements in the circuar queue are 10@ 20@ 30@ 40@
# Deleted Value =  10
# Deleted Value =  20
# elements in the circuar queue are 30@ 40@
# elements in circular queue are 30. 40. 5.
# 6# 7#
# queue is full

# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.queue = [None for i in range(size)]
        self.rear = -1
        self.front = -1
        
    def enqueue(self, data):
        if (self.rear + 1) % self.size == self.front :
            print('queue is Full')
            return
        elif self.rear == -1 and self.front ==-1:
            self.rear = 0
            self.front = 0
            self.queue[self.rear] = data
        else:
            self.rear = (self.rear + 1) % self.size
            self.queue[self.rear] = data
    
    def dequeue(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        elif self.rear == self.front:
            temp = self.queue[self.front]
            self.rear = -1
            self.front = -1
            return temp
        else:
            temp = self.queue[self.front]
            self.front = (self.front + 1) % self.size
            return temp
        
    def display(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        elif self.rear >= self.front:
            print('elements in the circular queue are',end= ' ')
            for i in range(self.front, self.rear+1):
                print(self.queue[i], end='@ ')
            print()
        else:
            print('elements in circular queue are',end= ' ')
            for i in range(self.front, self.size):
                print(self.queue[i],end='. ')
            print()
            for i in range(0, self.rear + 1):
                print(self.queue[i],end=', ')
            print()
            
cq = CircularQueue(5)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(40)
cq.display()
print('deleted element = ',cq.dequeue())
print('deleted element = ',cq.dequeue())
cq.display()
cq.enqueue(50)
cq.enqueue(60)
cq.enqueue(70)
cq.display()
# Out:
# elements in the circular queue are 10@ 20@ 30@ 40@
# deleted element =  10
# deleted element =  20
# elements in the circular queue are 30@ 40@
# elements in circular queue are 30. 40. 50.
# 60, 70,

# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.queue = [None for i in range(size)]
        self.rear = -1
        self.front = -1
        
    def enqueue(self, data):
        if (self.rear + 1) % self.size == self.front:
            print('queue is Full')
            return
        elif self.rear == -1 and self.front ==-1 :
            self.rear = 0
            self.front = 0
            self.queue[self.rear] = data
        else:
            self.rear = (self.rear + 1) % self.size
            self.queue[self.rear] = data
        
    def dequeue(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        elif self.rear == self.front:
            temp = self.queue[self.front]
            self.rear = -1
            self.front = -1
            return temp
        else:
            temp = self.queue[self.front]
            self.front = (self.front + 1) % self.size
            return temp
            
    def display(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        elif self.rear >= self.front:
            print('elements of enqueue = ',end=' ')
            for i in range(self.front , self.rear + 1 ):
                print(self.queue[i], end= ' ')
            print()
        else:
            print('elements in queue are',end=' ')
            for i in range(self.front , self.size):
                
                print(self.queue[i],end=' ')
            print()
            for i in range(0 , self.rear+1):
                print(self.queue[i],end=' ')
            print()
        
        if self.rear == (self.rear + 1) % self.size :
            print('list is full')
            return
cq = CircularQueue(5)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(70)
cq.display()
print('deleted nodes are', cq.dequeue())
print('deleted nodes are', cq.dequeue())
cq.display()
cq.enqueue(40)
cq.enqueue(50)
cq.display()
# Out:
# elements of enqueue =  10 20 30 70
# deleted nodes are 10
# deleted nodes are 20
# elements of enqueue =  30 70
# elements in queue are 30 70 40
# 50

# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.queue = [None for i in range(size)]
        self.rear = self.front = -1
    def enqueue(self, data):
        if (self.rear + 1) % self.size == self.front :
            print('queue is Full')
            return
        elif self.rear == -1 and self.front ==-1:
            self.rear = 0
            self.front = 0
            self.queue[self.rear] = data
        else:
            self.rear = (self.rear + 1) % self.size 
            self.queue[self.rear] = data
    def dequeue(self):
        if self.rear == -1 and self.front == -1:
            print('queue is already empty')
            return
        elif self.rear == self.front:
            temp = self.queue[self.front]
            self.rear = -1
            self.front = -1
            return temp
        else:
            temp = self.queue[self.front]
            self.front = (self.front + 1) % self.size
            return temp
        
    def display(self):
        if self.rear == -1 and self.front == -1:
            print('queue is empty')
            return
        elif self.rear >= self.front :
            print('elements in the queue :',end = ' ')
            for i in range(self.front , self.rear + 1):
                print(self.queue[i], end=' ')
                
            print()
        else:
            print('elements in queue: ',end= ' ')
            for i in range(self.front , self.size):
                print(self.queue[i], end=' ')
                
            print()
            for i in range(0, self.rear + 1):
                print(self.queue[i], end=' ')
                
            print()
        if (self.rear + 1) % self.size == self.front:
            print('queue is Full')
            return
        
cq = CircularQueue(4)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(70)
cq.display()
print('deleted nodes are', cq.dequeue())
print('deleted nodes are', cq.dequeue())
cq.display()
cq.enqueue(40)
cq.enqueue(50)
cq.display()
# Out:
# elements in the queue : 10 20 30 70
# queue is Full
# deleted nodes are 10
# deleted nodes are 20
# elements in the queue : 30 70
# elements in queue:  30 70
# 40 50
# queue is Full

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
class BST:
    def __init__(self, root= None):
        self.root = root
        
    def get_root(self):
        return self.root
    
    def insert(self, data):
        if self.root is None:
            self.root = Node(data)
        else:
            self.insert_helper(self.root , data)
            
    def insert_helper(self, cur_node , data):
        if data < cur_node.data:
            if cur_node.left is None:
                cur_node.left = Node(data)
            else:
                self.insert_helper(cur_node.left , data)
        else:
            if cur_node.right is None:
                cur_node.right = Node(data)
            else:
                self.insert_helper(cur_node.right , data)

    def find_inorder_successor(self, cur_node):   # smallest from right child
        my_val = cur_node
        while my_val.left is not None:
            my_val = my_val.left
        return my_val
    
    def deleteNode(self, cur_node, data):
        if cur_node is None:
            return cur_node
        
        if data < cur_node.data:
            cur_node.left = self.deleteNode(cur_node.left , data)
        elif data > cur_node.data:
            cur_node.right = self.deleteNode(cur_node.right , data)
        else:
            #no child or 1 child   #complete Tree
            if cur_node.left is None:
                temp = cur_node.right
                cur_node = None
                return temp
            elif cur_node.right is None:
                temp = cur_node.left 
                cur_node = None
                return temp
            # case with two children
            
            temp = self.find_inorder_successor(cur_node.right)
            
            cur_node.data = temp.data
            cur_node.right = self.deleteNode(cur_node.right , temp.data)
        return cur_node
            
    def search(self, cur_node , data):
        if cur_node is None:
            print('data not found')
            return False
        elif cur_node.data == data:
            print('data found')
            return True
        elif data < cur_node.data:
            cur_node.left = self.search(cur_node.left , data)
        else:
            cur_node.right = self.search(cur_node.right , data)
    
    def inOrder(self, cur_node ):
        if cur_node:
            self.inOrder(cur_node.left)
            print(cur_node.data ,',', end=' ')
            self.inOrder(cur_node.right)
            
    def preOrder(self, cur_node):
        if cur_node:
            print(cur_node.data,',',end=' ')
            self.preOrder(cur_node.left)
            self.preOrder(cur_node.right)
            
    def postOrder(self, cur_node):
        if cur_node:
            self.postOrder(cur_node.left)
            self.postOrder(cur_node.right)
            print(cur_node.data,',',end=' ')
            
    def printTree(self):
        if self.root != None:
            self.printTree_helper(self.root)
            
    def printTree_helper(self, cur_node):
        if cur_node != None:
            self.printTree_helper(self, cur_node.left)
            print(cur_node.data)
            self.printTree_helper(self, cur_node.right)
            

# Driver program to test the above functions 
# Let us create the following BST 
#      50 
#    /      \ 
#   30     70 
#   / \    / \ 
#  20 40  60 80 
  
# Print inoder traversal of the BST

# %%
class Node :
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
class BST :
    def __init__(self, root= None):
        self.root = root
        
    def insert(self, data):
        if self.root is None:
            self.root = Node(data)
        else:
            self._insert(self.root , data)
            
    def _insert(self, cur_node, data):
        if data < cur_node.data:
            if cur_node.left is None:
                cur_node.left = Node(data)
            else:
                self._insert(cur_node.left , data)
        else:
            if cur_node.right is None:
                cur_node.right = Node(data)
            else:
                self._insert(cur_node.right ,data)
        
    def inOrderSuccessor(self, cur_node):
        myVal = cur_node
        while myVal.left is not None:
            myVal = myVal.left
        return myVal
    def deleteNode (self, cur_node, data):
        if cur_node is None :
            return cur_node
        if data < cur_node.left :
            cur_node.left = deleteNode(cur_node.left, data)
        elif data > cur_node.right:
            cur_node.right  deleteNode(cur_node.right, data)
        else:
            # 1 or 0 child
            if cur_node.left is None:
                temp = cur_node.right
                cur_node = None
                return temp
            elif cur_node.right is None:
                temp = cur_node.left 
                cur_node = None
                return temp
            else:
                temp = self.inOrderSuccessor(cur_node.right)
                
            cur_node.data = temp.data
            cur_node.right = self.deleteNode(cur_node.right , temp.data)
        return cur_node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
class BST:
    def __init__(self, root = None):
        self.root = root
    def insert(self, data):
        if self.root is None:
            self.root = Node(data)
        else:
            _insert(self.root , data)
    def _insert(self, cur_data, data):
        if data < cur_data.data :
            if cur_data.left is None:
                cur_data.left = Node(data)
            else:
                self._insert(cur_data.left , data)
                
        else:
            if cur_data.right is None:
                cur_data.right = Node(data)
            else:
                self._insert(cur_data.right, data)
    def inOrderSuccessor(self, data):
        myVal = cur_data
        while myVal.left is not None:
            myVal = myVal.left
        return myVal
    def deleteNode(self, cur_data , data):
        if data < cur_data.data:
            cur_data.left = self.deleteNode(cur_data.left , data)
        elif data > cur_data.data:
            cur_data.right = self.deleteNode(cur_data.right , data)
        else:
            #0 or 1 child
            if cur_data.left is None:
                temp = cur_data.right
                cur_data = None
                return temp
            elif cur_data.right is None:
                temp = cur_data.left 
                cur_data = None
                return temp
            else:
                #2 child
            temp = self.inOrderSuccessor(cur_data.right)
            
            cur_data.data = temp.data
            cur_data.right = self.deleteNode(cur_data.right, temp.data)
        return cur_data
    
    def search(self, cur_data , data):
        if cur_data is None:
            print('data not found')
            return False
        elif cur_data.data == data:
            print('data found')
            return True
        elif data < cur_data.data:
            self.search(cur_data.left , data)
        else:
            self.search(cur_data.right, data)
    
    def inOrder(self, cur_data):
        if cur_data:
            self.inOrder(cur_data.left)
            print(cur_data.data,',',end=' ')
            self.inOrder(cur_data.right)
            
    def preOrder(self, cur_data):
        if cur_data:
            print(cur_data.left)
            self.preOrder(cur_data.left)
            self.preOrder(cur_data.right)
            
    def postOrder(self, cur_data):
        if cur_data:
            
            self.preOrder(cur_data.left)
            self.preOrder(cur_data.right)
            print(cur_data.left)

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None
        self.height = 1
class AVT_TREE:
    def getHeight(self, root):
        if not root:
            return 0
        return root.height
    
    def getBalance(self, root):
        if not root:
            return 0
        return self.getHeight(root.left) - self.getHeight(root.right)
    
    def rightRotate(self,z):
        y = z.left
        T3 = y.right
        
        #right rotate
        y.right = z
        z.left = T3
        
        z.height = 1 + max(self.getHeight(z.left) , self.getHeight(z.right))
        y.height = 1 + max(self.getHeight(y.left) , self.getHeight(y.right))
        return y
    
    def leftRotate(self, z):
        y = z.right
        T2 = y.left
        
        #left rotate
        y.left = z
        z.right = T2
        
        z.height = 1 + max(self.getHeight(z.left) , self.getHeight(z.right))
        y.height = 1 + max(self.getHeight(y.left) , self.getHeight(y.right))
        return y
    
    def insert(self, root, data):
        if not root:
            return Node(data)
        if data < root.val:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)
            
        # updating height
        root.height = 1 + max(self.getHeight(root.left) , self.getHeight(root.right))
    
        # balance nodes
        balance = self.getBalance(root)
        
        if balance > 1 and data < root.left.val:
            return self.rightRotate(root)
        #right right
        if balance < -1 and data > root.right.val:
            return self.leftRotate(root)
        if balance > 1 and data > root.left.val:
            root.left = self.leftRotate(root.left)
            return self.rightRotate(root)
        if balance < -1 and data < root.right.val:
            root.right = self.rightRotate(root.right)
            return self.leftRotate(root)
        return root
         
    def delete(self, root, data):
        if not root:
            return root
        elif data < root.val:
            root.left = self.delete(root.left, data)
        elif data > root.val:
            root.right = self. delete(root.right, data)
        else:
            if root.left is None:
                temp = root.right
                root = None
                return temp
            
            elif root.right is None:
                temp = root.left
                root = None
                return temp
            
            temp = self.inOrderSuccessor(root.right)
            root.val = temp.val
            root.right = self.delete(root.right, temp.val)
            
        if root is None:
            return root
        
        #update the height
        root.height = 1 + max(self.getHeight(root.left) , self.getHeight(root.right))
        
        #balancing
        balance = self.getBalance(root)
        
        # unbalancing nodes
        #left left
        if balance > 1 and self.getBalance(root.left) >= 0: 
            return self.rightRotate(root) 
  
        # Case 2 - Right Right 
        if balance < -1 and self.getBalance(root.right) <= 0: 
            return self.leftRotate(root) 
  
        # Case 3 - Left Right 
        if balance > 1 and self.getBalance(root.left) < 0: 
            root.left = self.leftRotate(root.left) 
            return self.rightRotate(root) 
  
        # Case 4 - Right Left 
        if balance < -1 and self.getBalance(root.right) > 0: 
            root.right = self.rightRotate(root.right) 
            return self.leftRotate(root) 
  
        return root
        
        
    def inOrderSuccessor(self, root):
        myVal = root
        while myVal is not None:
            myVal = myVal.left
        return myVal
    
    def preOrder(self, root):
        if not root:
            return 
        print('{0}'.format(root.val), end='   ')
        self.preOrder(root.left)
        self.preOrder(root.right)
        
myTree= AVT_TREE()
root = None
nums = [9, 5, 10, 0, 6, 11, -1, 1, 2] 
  
for num in nums: 
    root = myTree.insert(root, num) 
  
# Preorder Traversal 
print("Preorder Traversal after insertion -") 
myTree.preOrder(root) 
print() 
  
# Delete 
data = 10
root = myTree.delete(root, data) 

# Preorder Traversal 
print("Preorder Traversal after deletion -") 
myTree.preOrder(root) 
print()
# Out:
# Preorder Traversal after insertion -
# 9   1   0   -1   5   2   6   10   11
# Preorder Traversal after deletion -
# 1   0   -1   9   5   2   6   11
